# %% [markdown]
# ## SK 유동인구 EDA 파일

# %%
import numpy as np
import pandas as pd
import datetime as dt
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import mean_squared_error

import os

# %%
FLOWTIME_PATH = '/Users/minki/pythonworkspace/bigcon2020/2020dataset/SK_data/FLOW_TIME'
FLOWAGE_PATH = '/Users/minki/pythonworkspace/bigcon2020/2020dataset/SK_data/FLOW_AGE'

# %%
sk_data_TIME = pd.read_excel(f'{FLOWTIME_PATH}/SK_TIME_DATA.xlsx')
sk_data_AGE = pd.read_excel(f'{FLOWAGE_PATH}/SK_AGE_DATA.xlsx')

del sk_data_TIME['Unnamed: 0']
del sk_data_AGE['Unnamed: 0']

# %% [markdown]
# ### EDA 데이터 2019, 2020으로 쪼개기

# %%
sk_TIME_2019 = sk_data_TIME[sk_data_TIME['STD_YM'] < 202000]
sk_TIME_2020 = sk_data_TIME[sk_data_TIME['STD_YM'] >= 202000]

sk_AGE_2019 = sk_data_AGE[sk_data_AGE['STD_YM'] < 202000]
sk_AGE_2020 = sk_data_AGE[sk_data_AGE['STD_YM'] >= 202000]

# %%
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path = '/Library/Fonts/NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_path, size=10).get_name()
plt.rc('font', family=font_name, size=12)
plt.rcParams["figure.figsize"] = (30, 10)
register_matplotlib_converters()

mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumGothic')

# %% [markdown]
# ## 1. 시간별 유동인구 EDA

# %%
sk_data_TIME['HDONG_NM'].value_counts(dropna = True, normalize = False)
# Out:
# 황학동       241
# 중계2.3동    241
# 중계본동      241
# 소공동       241
# 회현동       241
#          ...
# 중림동       241
# 지산2동      241
# 성내3동      241
# 삼덕동       241
# 하계2동      241
# Name: HDONG_NM, Length: 69, dtype: int64

# %% [markdown]
# ### 서울, 대구 총 69개의 동이 있음을 확인할 수 있고, 각각 241개의 데이터가 존재함

# %% [markdown]
# ### 1-1. 월별 도시별 유동인구

# %%
sk_month_move = sk_data_TIME.groupby([sk_data_TIME['STD_YM'], sk_data_TIME['CITY']]).sum().iloc[:, 2:]

# %%
sk_month_move.T.plot(kind = 'bar')
plt.title('도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 15)

# %%
sk_month_move.plot(kind = 'bar')
plt.title('도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 15)

# %% [markdown]
# ### - 일반적으로 서울시의 유동인구가 대구시보다 많고, 출근시간인 7-9시와 퇴근시간인 17-19시가 다른 시간대보다 유동인구가 많은것을 볼 수 있음.

# %% [markdown]
# ### 1-2. 월별 도시별 유동인구 (세부)

# %%
sk_month_move.T.iloc[:, 0:2].plot(kind = 'bar')
plt.title('2019년 2월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 2:4].plot(kind = 'bar')
plt.title('2019년 3월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 4:6].plot(kind = 'bar')
plt.title('2019년 4월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 6:8].plot(kind = 'bar')
plt.title('2019년 5월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 8:10].plot(kind = 'bar')
plt.title('2020년 2월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 10:12].plot(kind = 'bar')
plt.title('2020년 3월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 12:14].plot(kind = 'bar')
plt.title('2020년 4월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, 14:16].plot(kind = 'bar')
plt.title('2020년 5월 도시별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %% [markdown]
# ## 2-1. 구별 시간대별 유동인구

# %%
sk_month_GU_move = sk_data_TIME.groupby([sk_data_TIME['STD_YM'], sk_data_TIME['GU_NAME']]).sum().iloc[:, 2:]

# %%
sk_month_GU_move.plot(kind = 'bar')
plt.title('구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 15)

# %%
sk_month_GU_move.T.plot(kind = 'bar')
plt.title('구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 15)

# %% [markdown]
# ### - 일반적으로 중구 > 수성구 > 노원구 순으로 유동인구가 많은 것으로 보임

# %% [markdown]
# ### 2-2. 구별 시간대별 유동인구 (세부)

# %%
sk_month_GU_move.T.iloc[:, 0:3].plot(kind = 'bar')
plt.title('2019년 2월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 3:6].plot(kind = 'bar')
plt.title('2019년 3월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 6:9].plot(kind = 'bar')
plt.title('2019년 4월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 9:12].plot(kind = 'bar')
plt.title('2019년 5월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 12:15].plot(kind = 'bar')
plt.title('2020년 2월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 15:18].plot(kind = 'bar')
plt.title('2020년 3월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 18:21].plot(kind = 'bar')
plt.title('2020년 4월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, 21:24].plot(kind = 'bar')
plt.title('2020년 5월 구별 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %% [markdown]
# ## 3-1. 코로나 전후 유동인구 비교
#
# #### 대구는 수성구 하나이므로 구별로 넘김

# %%
sk_month_move.T.iloc[:, [1, 9]].plot(kind = 'bar')
plt.title('코로나 전후 2월 서울특별시 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, [3, 11]].plot(kind = 'bar')
plt.title('코로나 전후 3월 서울특별시 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, [5, 13]].plot(kind = 'bar')
plt.title('코로나 전후 4월 서울특별시 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move.T.iloc[:, [7, 15]].plot(kind = 'bar')
plt.title('코로나 전후 5월 서울특별시 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [0, 12]].plot(kind = 'bar')
plt.title('코로나 전후 2월 노원구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [3, 15]].plot(kind = 'bar')
plt.title('코로나 전후 3월 노원구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [6, 18]].plot(kind = 'bar')
plt.title('코로나 전후 4월 노원구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [9, 21]].plot(kind = 'bar')
plt.title('코로나 전후 5월 노원구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [1, 13]].plot(kind = 'bar')
plt.title('코로나 전후 2월 수성구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [4, 16]].plot(kind = 'bar')
plt.title('코로나 전후 3월 수성구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [7, 19]].plot(kind = 'bar')
plt.title('코로나 전후 4월 수성구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [10, 22]].plot(kind = 'bar')
plt.title('코로나 전후 5월 수성구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [2, 14]].plot(kind = 'bar')
plt.title('코로나 전후 2월 중구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [5, 17]].plot(kind = 'bar')
plt.title('코로나 전후 3월 중구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [8, 20]].plot(kind = 'bar')
plt.title('코로나 전후 4월 중구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_GU_move.T.iloc[:, [11, 23]].plot(kind = 'bar')
plt.title('코로나 전후 5월 중구 시간대별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %% [markdown]
# # 2. 연령별 유동인구 EDA

# %%
sk_month_move_AGE = sk_data_AGE.groupby([sk_data_TIME['STD_YM'], sk_data_TIME['CITY']]).sum().iloc[:, 3:]

# %%
sk_month_move_AGE.T
# Out:
# STD_YM                      201902                  201903              \
# CITY                         대구광역시       서울특별시       대구광역시       서울특별시
# MAN_FLOW_POP_CNT_0004       761.11      806.27     1017.92      932.70
# MAN_FLOW_POP_CNT_0509    113026.86   119519.48   151680.87   134506.43
# MAN_FLOW_POP_CNT_1014    540092.30   594073.59   605058.31   569997.29
# MAN_FLOW_POP_CNT_1519   1267585.14  1440681.04  1839815.53  1784091.10
# MAN_FLOW_POP_CNT_2024   2295871.97  2442563.78  3077991.43  2778270.94
# MAN_FLOW_POP_CNT_2529   3281783.70  3608482.89  3917790.33  3874415.77
# MAN_FLOW_POP_CNT_3034   3533345.56  3871042.18  4204894.20  4137169.03
# MAN_FLOW_POP_CNT_3539   4365996.78  4759177.63  5289803.57  5065197.01
# MAN_FLOW_POP_CNT_4044   4279062.70  4671950.40  5242731.13  4976872.70
# MAN_FLOW_POP_CNT_4549   5161557.95  5645959.77  6368822.94  6048858.43
# MAN_FLOW_POP_CNT_5054   4850122.47  5273196.26  5979647.33  5640889.00
# MAN_FLOW_POP_CNT_5559   4535845.25  4918763.64  5603015.57  5242503.56
# MAN_FLOW_POP_CNT_6064   4187875.09  4531830.11  5180684.50  4914340.34
# MAN_FLOW_POP_CNT_6569   2901878.37  3126919.09  3599924.70  3414034.42
# MAN_FLOW_POP_CNT_70U    3028707.86  3266919.01  3808765.35  3585162.82
# WMAN_FLOW_POP_CNT_0004      258.86      245.73      251.28      340.21
# WMAN_FLOW_POP_CNT_0509   144409.21   155530.23   185250.93   166869.12
# WMAN_FLOW_POP_CNT_1014   594680.91   648084.62   637356.21   608640.03
# WMAN_FLOW_POP_CNT_1519  1340318.46  1486344.38  1926253.45  1856392.16
# WMAN_FLOW_POP_CNT_2024  2679515.96  2900073.19  3894582.04  3640710.53
# WMAN_FLOW_POP_CNT_2529  3072612.01  3370585.25  3634165.40  3735926.09
# WMAN_FLOW_POP_CNT_3034  2812679.33  3079530.10  3326402.13  3364260.15
# WMAN_FLOW_POP_CNT_3539  3290111.06  3574790.14  3946346.48  3768252.19
# WMAN_FLOW_POP_CNT_4044  3314333.95  3655506.29  4086981.61  3852755.46
# WMAN_FLOW_POP_CNT_4549  3818042.40  4220448.23  4762034.06  4482156.53
# WMAN_FLOW_POP_CNT_5054  3323288.72  3650470.70  4151335.69  3817611.46
# WMAN_FLOW_POP_CNT_5559  3077831.44  3332016.71  3893734.79  3520198.16
# WMAN_FLOW_POP_CNT_6064  2558228.92  2737098.05  3272500.65  2951141.29
# MAN_FLOW_POP_CNT_0509     79133.01    80159.01   112761.75    95512.95
# MAN_FLOW_POP_CNT_1014    453910.88   432159.44   573324.30   511854.44
# MAN_FLOW_POP_CNT_1519    957134.52   928783.83  1171790.17  1098056.27
# MAN_FLOW_POP_CNT_2024   1622843.52  1761524.78  2191191.80  1857305.90
# MAN_FLOW_POP_CNT_2529   2549937.93  2886230.11  3103924.34  2993210.28
# MAN_FLOW_POP_CNT_3034   2795774.72  3187393.81  3359147.19  3240980.24
# MAN_FLOW_POP_CNT_3539   3460338.63  3944849.55  4135828.49  3911215.30
# MAN_FLOW_POP_CNT_4044   3677550.89  4180250.70  4386285.80  4127928.35
# MAN_FLOW_POP_CNT_4549   4282619.03  4841538.88  5092662.83  4801318.34
# MAN_FLOW_POP_CNT_5054   4258211.10  4776985.57  5075582.89  4717128.86
# MAN_FLOW_POP_CNT_5559   3695748.65  4193794.14  4450583.43  4088707.25
# MAN_FLOW_POP_CNT_6064   3389357.65  3813153.20  4116987.65  3748919.98
# MAN_FLOW_POP_CNT_6569   2428608.03  2712798.61  2957579.49  2711470.14
# MAN_FLOW_POP_CNT_70U    2564244.12  2805662.93  3201499.74  2896429.27
# WMAN_FLOW_POP_CNT_0004        8.07        2.58       33.68       30.26
# WMAN_FLOW_POP_CNT_0509   102003.32   104076.55   141107.99   121342.73
# WMAN_FLOW_POP_CNT_1014   453923.37   447687.78   591710.34   527533.34
# WMAN_FLOW_POP_CNT_1519   903727.03   899404.06  1132516.18  1102565.18
# WMAN_FLOW_POP_CNT_2024  1837776.26  1987359.43  2321485.38  2191089.80
# WMAN_FLOW_POP_CNT_2529  2392850.56  2699302.90  2873374.27  2817446.60
# WMAN_FLOW_POP_CNT_3034  2146348.97  2412887.38  2592696.88  2519784.01
# WMAN_FLOW_POP_CNT_3539  2416766.19  2688868.55  2991728.77  2799986.01
# WMAN_FLOW_POP_CNT_4044  2678408.11  2925310.72  3334338.91  3062756.17
# WMAN_FLOW_POP_CNT_4549  3139758.61  3441366.48  3883847.26  3559482.08
# WMAN_FLOW_POP_CNT_5054  2860339.62  3196772.49  3611677.21  3227272.37
# WMAN_FLOW_POP_CNT_5559  2531841.09  2823064.88  3214124.81  2823964.23
# WMAN_FLOW_POP_CNT_6064  2262327.54  2492930.43  2904864.60  2525060.83
# WMAN_FLOW_POP_CNT_6569  1479165.40  1628408.51  1949189.26  1674815.38
# WMAN_FLOW_POP_CNT_70U   1812404.30  1971104.97  2420642.62  2053131.81

# %% [markdown]
# ### 2-1. 연령별 유동인구

# %%
sk_month_move_AGE.T.iloc[:, [0, 8]].plot(kind = 'bar')
plt.title('코로나 전후 2월 중구 연령별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)

# %%
sk_month_move_AGE.T.iloc[:, [1, 9]].plot(kind = 'bar')
plt.title('코로나 전후 2월 중구 연령별 유동인구', fontsize = 30)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(fontsize = 30)
